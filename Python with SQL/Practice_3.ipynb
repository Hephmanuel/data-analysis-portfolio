# %%
import pandas as pd
import sqlite3
import csv

conn = sqlite3.connect("FinalDB.db")
cur = conn.cursor()

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01",
           )
df.to_sql('CENSUS_DATA', conn, if_exists = 'replace', index = False, method = 'multi')

dg = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01"
                )
dg.to_sql('PUBLIC_SCHOOLS_DATA', conn, if_exists = 'replace', index = False, method = 'multi')

dh = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01"
                )
dh.to_sql('CRIME_DATA',conn, if_exists = 'replace', index = False, method = 'multi' )
# Out:
# 533

# %%
# %sql sqlite:///FinalDB.db

# %%
# %%sql SELECT name, type, length(type)
# from PRAGMA_TABLE_INFO('CRIME_DATA');
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('ID', 'INTEGER', 7),
#  ('CASE_NUMBER', 'TEXT', 4),
#  ('DATE', 'TEXT', 4),
#  ('BLOCK', 'TEXT', 4),
#  ('IUCR', 'TEXT', 4),
#  ('PRIMARY_TYPE', 'TEXT', 4),
#  ('DESCRIPTION', 'TEXT', 4),
#  ('LOCATION_DESCRIPTION', 'TEXT', 4),
#  ('ARREST', 'INTEGER', 7),
#  ('DOMESTIC', 'INTEGER', 7),
#  ('BEAT', 'INTEGER', 7),
#  ('DISTRICT', 'INTEGER', 7),
#  ('WARD', 'REAL', 4),
#  ('COMMUNITY_AREA_NUMBER', 'REAL', 4),
#  ('FBICODE', 'TEXT', 4),
#  ('X_COORDINATE', 'REAL', 4),
#  ('Y_COORDINATE', 'REAL', 4),
#  ('YEAR', 'INTEGER', 7),
#  ('LATITUDE', 'REAL', 4),
#  ('LONGITUDE', 'REAL', 4),
#  ('LOCATION', 'TEXT', 4)]

# %%
# %sql SELECT COUNT(*) FROM CRIME_DATA;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(533,)]

# %%
# %%sql SELECT name, type, length(type)
# from PRAGMA_TABLE_INFO('PUBLIC_SCHOOLS_DATA');
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('School_ID', 'INTEGER', 7),
#  ('NAME_OF_SCHOOL', 'TEXT', 4),
#  ('Elementary, Middle, or High School', 'TEXT', 4),
#  ('Street_Address', 'TEXT', 4),
#  ('City', 'TEXT', 4),
#  ('State', 'TEXT', 4),
#  ('ZIP_Code', 'INTEGER', 7),
#  ('Phone_Number', 'TEXT', 4),
#  ('Link', 'TEXT', 4),
#  ('Network_Manager', 'TEXT', 4),
#  ('Collaborative_Name', 'TEXT', 4),
#  ('Adequate_Yearly_Progress_Made_', 'TEXT', 4),
#  ('Track_Schedule', 'TEXT', 4),
#  ('CPS_Performance_Policy_Status', 'TEXT', 4),
#  ('CPS_Performance_Policy_Level', 'TEXT', 4),
#  ('HEALTHY_SCHOOL_CERTIFIED', 'TEXT', 4),
#  ('Safety_Icon', 'TEXT', 4),
#  ('SAFETY_SCORE', 'REAL', 4),
#  ('Family_Involvement_Icon', 'TEXT', 4),
#  ('Family_Involvement_Score', 'TEXT', 4),
#  ('Environment_Icon', 'TEXT', 4),
#  ('Environment_Score', 'REAL', 4),
#  ('Instruction_Icon', 'TEXT', 4),
#  ('Instruction_Score', 'REAL', 4),
#  ('Leaders_Icon', 'TEXT', 4),
#  ('Leaders_Score', 'TEXT', 4),
# ...

# %%
# %%sql SELECT COMMUNITY_AREA_NAME, COMMUNITY_AREA_NUMBER
# FROM CENSUS_DATA
# WHERE PER_CAPITA_INCOME < 11000;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('West Garfield Park', 26.0),
#  ('South Lawndale', 30.0),
#  ('Fuller Park', 37.0),
#  ('Riverdale', 54.0)]

# %%
# %%sql SELECT CASE_NUMBER,description
# FROM CRIME_DATA
# WHERE DESCRIPTION LIKE '%minor%';
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('HL266884', 'SELL/GIVE/DEL LIQUOR TO MINOR'),
#  ('HK238408', 'ILLEGAL CONSUMPTION BY MINOR')]

# %%
# %%sql SELECT ID, CASE_NUMBER, DESCRIPTION, primary_type
# FROM CRIME_DATA
# WHERE PRIMARY_TYPE LIKE '%kidnapping%' AND DESCRIPTION LIKE '%CHILD%'
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(5276766, 'HN144152', 'CHILD ABDUCTION/STRANGER', 'KIDNAPPING')]

# %%
# %%sql SELECT DISTINCT(PRIMARY_TYPE)
# FROM CRIME_DATA;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('THEFT',),
#  ('BATTERY',),
#  ('CRIMINAL DAMAGE',),
#  ('NARCOTICS',),
#  ('OTHER OFFENSE',),
#  ('ASSAULT',),
#  ('BURGLARY',),
#  ('MOTOR VEHICLE THEFT',),
#  ('DECEPTIVE PRACTICE',),
#  ('ROBBERY',),
#  ('CRIMINAL TRESPASS',),
#  ('PROSTITUTION',),
#  ('WEAPONS VIOLATION',),
#  ('PUBLIC PEACE VIOLATION',),
#  ('OFFENSE INVOLVING CHILDREN',),
#  ('CRIM SEXUAL ASSAULT',),
#  ('SEX OFFENSE',),
#  ('INTERFERENCE WITH PUBLIC OFFICER',),
#  ('GAMBLING',),
#  ('LIQUOR LAW VIOLATION',),
#  ('ARSON',),
#  ('HOMICIDE',),
#  ('KIDNAPPING',),
#  ('INTIMIDATION',),
#  ('STALKING',),
#  ('OBSCENITY',),
#  ('CONCEALED CARRY LICENSE VIOLATION',),
#  ('PUBLIC INDECENCY',),
#  ('NON-CRIMINAL',),
#  ('OTHER NARCOTIC VIOLATION',),
#  ('HUMAN TRAFFICKING',),
#  ('NON - CRIMINAL',),
#  ('RITUALISM',),
#  ('NON-CRIMINAL (SUBJECT SPECIFIED)',),
#  ('DOMESTIC VIOLENCE',)]

# %%
# %%sql SELECT DISTINCT(PRIMARY_TYPE)
# FROM CRIME_DATA
# WHERE LOCATION_DESCRIPTION LIKE '%school%'
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('BATTERY',),
#  ('CRIMINAL DAMAGE',),
#  ('NARCOTICS',),
#  ('ASSAULT',),
#  ('CRIMINAL TRESPASS',),
#  ('PUBLIC PEACE VIOLATION',)]

# %%
# %%sql
# SELECT DISTINCT "Elementary, Middle, or High SchooL", ROUND(AVG(SAFETY_SCORE), 2)
# FROM PUBLIC_SCHOOLS_DATA
# GROUP BY 1;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('ES', 49.52), ('HS', 49.62), ('MS', 48.0)]

# %%
# %%sql
# SELECT name,type,length(type) FROM PRAGMA_TABLE_INFO("CENSUS_DATA");
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('COMMUNITY_AREA_NUMBER', 'REAL', 4),
#  ('COMMUNITY_AREA_NAME', 'TEXT', 4),
#  ('PERCENT_OF_HOUSING_CROWDED', 'REAL', 4),
#  ('PERCENT_HOUSEHOLDS_BELOW_POVERTY', 'REAL', 4),
#  ('PERCENT_AGED_16__UNEMPLOYED', 'REAL', 4),
#  ('PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA', 'REAL', 4),
#  ('PERCENT_AGED_UNDER_18_OR_OVER_64', 'REAL', 4),
#  ('PER_CAPITA_INCOME', 'INTEGER', 7),
#  ('HARDSHIP_INDEX', 'REAL', 4)]

# %%
# %load_ext sql

# %%
# %%sql
# SELECT COMMUNITY_AREA_NAME, PERCENT_HOUSEHOLDS_BELOW_POVERTY
# FROM CENSUS_DATA
# ORDER BY PERCENT_HOUSEHOLDS_BELOW_POVERTY DESC
# LIMIT 5;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Riverdale', 56.5),
#  ('Fuller Park', 51.2),
#  ('Englewood', 46.6),
#  ('North Lawndale', 43.1),
#  ('East Garfield Park', 42.4)]

# %%
# %%sql
# SELECT cd.COMMUNITY_AREA_NUMBER
# FROM CRIME_DATA cd, CENSUS_DATA cn
# where cd.COMMUNITY_AREA_NUMBER = cn.COMMUNITY_AREA_NUMBER
# GROUP BY cd.COMMUNITY_AREA_NUMBER
# ORDER BY COUNT(*) DESC
# LIMIT 1;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(25.0,)]

# %%
# %%sql
# SELECT COMMUNITY_AREA_NAME
# FROM CENSUS_DATA
# WHERE HARDSHIP_INDEX IN (SELECT MAX(HARDSHIP_INDEX) FROM CENSUS_DATA);
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Riverdale',)]

# %%
# %%sql
# SELECT COMMUNITY_AREA_NAME
# FROM CENSUS_DATA
# WHERE COMMUNITY_AREA_NUMBER = (
#     SELECT COMMUNITY_AREA_NUMBER
#     FROM CRIME_DATA
#     GROUP BY COMMUNITY_AREA_NUMBER
#     ORDER BY COUNT(*) DESC
#     LIMIT 1
# );
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Austin',)]
